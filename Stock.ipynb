# %%
# !pip install textblob
# !pip install seaborn
# !pip install pandas

# %%
## Download the data file
# !wget https://www.dropbox.com/s/88zfcbdxzi3yei5/Combined_News_DJIA.csv

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
data = pd.read_csv('Combined_News_DJIA.csv')

# %%
data.columns
# Out:
# Index(['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
#        'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
#        'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
#        'Top24', 'Top25'],
#       dtype='object')

# %%
data.head(20)
# Out:
#           Date  ...                                              Top25
# 0   2008-08-08  ...           b"No Help for Mexico's Kidnapping Surge"
# 1   2008-08-11  ...  b"So this is what it's come to: trading sex fo...
# 2   2008-08-12  ...  b"BBC NEWS | Asia-Pacific | Extinction 'by man...
# 3   2008-08-13  ...  b'2006: Nobel laureate Aleksander Solzhenitsyn...
# 4   2008-08-14  ...  b'Philippines : Peace Advocate say Muslims nee...
# 5   2008-08-15  ...  b'Rivals say they plan to remove Georgian pres...
# 6   2008-08-18  ...         b'Mayor Asks Ugly Women To Visit His Town'
# 7   2008-08-19  ...               b'Blaze engulfs Egyptian parliament'
# 8   2008-08-20  ...      b'The First Solar Radio Station in Argentina'
# 9   2008-08-21  ...  b"International Olympic Committee launches pro...
# 10  2008-08-22  ...         b'Olympics Medal time line 1896 at 2008  '
# 11  2008-08-25  ...  b"UK child protection database 'will be used t...
# ...

# %%
from textblob import TextBlob

# Score value between 
def sentiment(t):
    score = TextBlob(str(t))
    return score.sentiment.polarity

# %%
sentiment("I am ok  with python")
# Out:
# 0.5

# %%
columns = ['Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
       'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
       'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
       'Top24', 'Top25']

# %%
for col in columns:
  data[col] = data[col].apply(lambda x: sentiment(x))

# %%
data.head()
# Out:
#          Date  Label  Top1  Top2  Top3  ...  Top21  Top22  Top23  Top24  Top25
# 0  2008-08-08      0     0     0     0  ...  -0.70      0      0  -0.10      0
# 1  2008-08-11      1     0 -0.16  0.10  ...      0      0      0   0.50      0
# 2  2008-08-12      0     0     0 -0.25  ...      0      0  -0.20   0.14      0
# 3  2008-08-13      0     0     0 -0.20  ...      0      0      0  -0.10      0
# 4  2008-08-14      1     0     0  0.40  ...      0      0      0   0.06      0
#
# [5 rows x 27 columns]

# %%
#pd.options.display.float_format = '{:.1f}'.format
pd.options.display.float_format = lambda x : '{:.0f}'.format(x) if int(x) == x else '{:,.2f}'.format(x)
data.head(100).style.background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
#     #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col1 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col2 {
#             background-color:  #ddf191;
#             color:  #000000;
#         }    #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col3 {
#             background-color:  #cbe982;
#             color:  #000000;
#         }    #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col4 {
#             background-color:  #e3f399;
#             color:  #000000;
#         }    #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col5 {
#             background-color:  #ddf191;
#             color:  #000000;
#         }    #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col6 {
#             background-color:  #fdb163;
#             color:  #000000;
#         }    #T_fdbf47de_b07a_11ea_b4f1_0242ac1c0002row0_col7 {
#             background-color:  #fee28f;
#             color:  #000000;
# ...
